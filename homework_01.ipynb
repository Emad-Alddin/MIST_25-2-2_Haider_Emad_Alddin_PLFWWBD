# %%
print("Меня зовут Емад Алддин, и я готов страдать на курсе")
# Out:
# Меня зовут Емад Алддин, и я готов страдать на курсе

# %% [markdown]
# # О себе
# Привет! Меня зовут Емад Алддин, я магистрант по специальности "Экосистема больших данных для цифровой трансформации".
# ## Мои интересы
# -🏢 **Умные здания.**
# -🤖 **искусственный интеллект.**
# ### Мои цели
# 1.  создавать практические проекты, особенно в сфере умных зданий.
# 2.  научиться решать сложные проблемы.

# %%
x=77
y=2
print("x%y", x%y)
# Out:
# x%y 1

# %%
a=22
if a%2==0:
    print("Четное число")
else:
    print("Нечетное число")
# Out:
# Четное число

# %%
86**7
# Out:
# 34792782221696
